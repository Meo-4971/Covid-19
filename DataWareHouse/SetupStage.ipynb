# %%
import pandas as pd
df = pd.read_csv('./owid-covid-data.csv', encoding= 'unicode_escape')

# %%
df
# Out:
#        iso_code continent     location       date  total_cases  new_cases
# 0           AFG      Asia  Afghanistan   1/3/2020          NaN        0.0  \
# 1           AFG      Asia  Afghanistan   1/4/2020          NaN        0.0
# 2           AFG      Asia  Afghanistan   1/5/2020          NaN        0.0
# 3           AFG      Asia  Afghanistan   1/6/2020          NaN        0.0
# 4           AFG      Asia  Afghanistan   1/7/2020          NaN        0.0
# ...         ...       ...          ...        ...          ...        ...
# 306318      ZWE    Africa     Zimbabwe  4/22/2023     264632.0        2.0
# 306319      ZWE    Africa     Zimbabwe  4/23/2023     264637.0        5.0
# 306320      ZWE    Africa     Zimbabwe  4/24/2023     264639.0        2.0
# 306321      ZWE    Africa     Zimbabwe  4/25/2023     264639.0        0.0
# 306322      ZWE    Africa     Zimbabwe  4/26/2023     264639.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# ...

# %%
StageLocation = df.iloc[:, [0,1,2]]
StageLocation = StageLocation.drop_duplicates()
StageLocation = StageLocation.fillna("Other")
StageLocation.isnull().sum()
# Out:
# iso_code     0
# continent    0
# location     0
# dtype: int64

# %%
StageLocation.to_csv('./StageLocation.csv', index=False)

# %%
StageDate = df.iloc[:, [3]]
StageDate = StageDate.drop_duplicates()
StageDate.isnull().sum()
# Out:
# date    0
# dtype: int64

# %%
StageDate.to_csv('./StageDate.csv', index=False)

# %%
StagePopulation = df.iloc[:, [0,62]]
StagePopulation = StagePopulation.drop_duplicates()
StagePopulation.isnull().sum()
# Out:
# iso_code      0
# population    0
# dtype: int64

# %%
StagePopulation.to_csv('./StagePopulation.csv', index=False)

# %%
StageConfirmedCases = df.iloc[:, [0, 3,5]]
StageConfirmedCases = StageConfirmedCases.drop_duplicates()
StageConfirmedCases = StageConfirmedCases.fillna(0)
StageConfirmedCases.isnull().sum()
# Out:
# iso_code     0
# date         0
# new_cases    0
# dtype: int64

# %%
StageConfirmedCases.to_csv('./StageConfirmedCases.csv', index=False)

# %%
StageConfirmedDeaths = df.iloc[:, [0,3,8]]
StageConfirmedDeaths = StageConfirmedDeaths.drop_duplicates()
StageConfirmedDeaths = StageConfirmedDeaths.fillna(0)
StageConfirmedDeaths.isnull().sum()
# Out:
# iso_code      0
# date          0
# new_deaths    0
# dtype: int64

# %%
StageConfirmedDeaths.to_csv('./StageConfirmedDeaths.csv', index=False)

# %%
StageTests = df.iloc[:,[0,3,26, 5]]
StageTests = StageTests.fillna(0)
StageTests
# Out:
#        iso_code       date  new_tests  new_cases
# 0           AFG   1/3/2020        0.0        0.0
# 1           AFG   1/4/2020        0.0        0.0
# 2           AFG   1/5/2020        0.0        0.0
# 3           AFG   1/6/2020        0.0        0.0
# 4           AFG   1/7/2020        0.0        0.0
# ...         ...        ...        ...        ...
# 306318      ZWE  4/22/2023        0.0        2.0
# 306319      ZWE  4/23/2023        0.0        5.0
# 306320      ZWE  4/24/2023        0.0        2.0
# 306321      ZWE  4/25/2023        0.0        0.0
# 306322      ZWE  4/26/2023        0.0        0.0
#
# [306323 rows x 4 columns]

# %%
StageTests['new_positive'] = StageTests['new_cases']
StageTests.isnull().sum()
# Out:
# iso_code        0
# date            0
# new_tests       0
# new_cases       0
# new_positive    0
# dtype: int64

# %%
StageTests['new_negative'] = StageTests['new_tests'] - StageTests['new_positive']
StageTests
# Out:
#        iso_code       date  new_tests  new_cases  new_positive  new_negative
# 0           AFG   1/3/2020        0.0        0.0           0.0           0.0
# 1           AFG   1/4/2020        0.0        0.0           0.0           0.0
# 2           AFG   1/5/2020        0.0        0.0           0.0           0.0
# 3           AFG   1/6/2020        0.0        0.0           0.0           0.0
# 4           AFG   1/7/2020        0.0        0.0           0.0           0.0
# ...         ...        ...        ...        ...           ...           ...
# 306318      ZWE  4/22/2023        0.0        2.0           2.0          -2.0
# 306319      ZWE  4/23/2023        0.0        5.0           5.0          -5.0
# 306320      ZWE  4/24/2023        0.0        2.0           2.0          -2.0
# 306321      ZWE  4/25/2023        0.0        0.0           0.0           0.0
# 306322      ZWE  4/26/2023        0.0        0.0           0.0           0.0
#
# [306323 rows x 6 columns]

# %%
StageTests = StageTests.iloc[:, [0,1,2,4,5]]
StageTests
# Out:
#        iso_code       date  new_tests  new_positive  new_negative
# 0           AFG   1/3/2020        0.0           0.0           0.0
# 1           AFG   1/4/2020        0.0           0.0           0.0
# 2           AFG   1/5/2020        0.0           0.0           0.0
# 3           AFG   1/6/2020        0.0           0.0           0.0
# 4           AFG   1/7/2020        0.0           0.0           0.0
# ...         ...        ...        ...           ...           ...
# 306318      ZWE  4/22/2023        0.0           2.0          -2.0
# 306319      ZWE  4/23/2023        0.0           5.0          -5.0
# 306320      ZWE  4/24/2023        0.0           2.0          -2.0
# 306321      ZWE  4/25/2023        0.0           0.0           0.0
# 306322      ZWE  4/26/2023        0.0           0.0           0.0
#
# [306323 rows x 5 columns]

# %%
StageTests.to_csv('./StageTests.csv', index=False)

# %%
StageFactStatify = df.iloc[:,[0,3,5,8,62]]
StageFactStatify = StageFactStatify.fillna(0)
StageFactStatify.isnull().sum()
# Out:
# iso_code      0
# date          0
# new_cases     0
# new_deaths    0
# population    0
# dtype: int64

# %%
StageFactStatify.to_csv('./StageFactStatify.csv', index=False)

# %%
StageFactTests = df.iloc[:,[0,3,5,26,62]]
StageFactTests = StageFactTests.fillna(0)
StageFactTests
# Out:
#        iso_code       date  new_cases  new_tests  population
# 0           AFG   1/3/2020        0.0        0.0    41128772
# 1           AFG   1/4/2020        0.0        0.0    41128772
# 2           AFG   1/5/2020        0.0        0.0    41128772
# 3           AFG   1/6/2020        0.0        0.0    41128772
# 4           AFG   1/7/2020        0.0        0.0    41128772
# ...         ...        ...        ...        ...         ...
# 306318      ZWE  4/22/2023        2.0        0.0    16320539
# 306319      ZWE  4/23/2023        5.0        0.0    16320539
# 306320      ZWE  4/24/2023        2.0        0.0    16320539
# 306321      ZWE  4/25/2023        0.0        0.0    16320539
# 306322      ZWE  4/26/2023        0.0        0.0    16320539
#
# [306323 rows x 5 columns]

# %%
StageFactTests['new_positive'] = StageFactTests['new_cases']
StageFactTests
# Out:
#        iso_code       date  new_cases  new_tests  population  new_positive
# 0           AFG   1/3/2020        0.0        0.0    41128772           0.0
# 1           AFG   1/4/2020        0.0        0.0    41128772           0.0
# 2           AFG   1/5/2020        0.0        0.0    41128772           0.0
# 3           AFG   1/6/2020        0.0        0.0    41128772           0.0
# 4           AFG   1/7/2020        0.0        0.0    41128772           0.0
# ...         ...        ...        ...        ...         ...           ...
# 306318      ZWE  4/22/2023        2.0        0.0    16320539           2.0
# 306319      ZWE  4/23/2023        5.0        0.0    16320539           5.0
# 306320      ZWE  4/24/2023        2.0        0.0    16320539           2.0
# 306321      ZWE  4/25/2023        0.0        0.0    16320539           0.0
# 306322      ZWE  4/26/2023        0.0        0.0    16320539           0.0
#
# [306323 rows x 6 columns]

# %%
StageFactTests['new_negative'] = StageFactTests['new_tests'] - StageFactTests['new_positive']
StageFactTests
# Out:
#        iso_code       date  new_cases  new_tests  population  new_positive
# 0           AFG   1/3/2020        0.0        0.0    41128772           0.0  \
# 1           AFG   1/4/2020        0.0        0.0    41128772           0.0
# 2           AFG   1/5/2020        0.0        0.0    41128772           0.0
# 3           AFG   1/6/2020        0.0        0.0    41128772           0.0
# 4           AFG   1/7/2020        0.0        0.0    41128772           0.0
# ...         ...        ...        ...        ...         ...           ...
# 306318      ZWE  4/22/2023        2.0        0.0    16320539           2.0
# 306319      ZWE  4/23/2023        5.0        0.0    16320539           5.0
# 306320      ZWE  4/24/2023        2.0        0.0    16320539           2.0
# 306321      ZWE  4/25/2023        0.0        0.0    16320539           0.0
# 306322      ZWE  4/26/2023        0.0        0.0    16320539           0.0
#
#         new_negative
# 0                0.0
# 1                0.0
# ...

# %%
StageFactTests = StageFactTests.iloc[:, [0,1,3,4,5,6]]
StageFactTests
# Out:
#        iso_code       date  new_tests  population  new_positive  new_negative
# 0           AFG   1/3/2020        0.0    41128772           0.0           0.0
# 1           AFG   1/4/2020        0.0    41128772           0.0           0.0
# 2           AFG   1/5/2020        0.0    41128772           0.0           0.0
# 3           AFG   1/6/2020        0.0    41128772           0.0           0.0
# 4           AFG   1/7/2020        0.0    41128772           0.0           0.0
# ...         ...        ...        ...         ...           ...           ...
# 306318      ZWE  4/22/2023        0.0    16320539           2.0          -2.0
# 306319      ZWE  4/23/2023        0.0    16320539           5.0          -5.0
# 306320      ZWE  4/24/2023        0.0    16320539           2.0          -2.0
# 306321      ZWE  4/25/2023        0.0    16320539           0.0           0.0
# 306322      ZWE  4/26/2023        0.0    16320539           0.0           0.0
#
# [306323 rows x 6 columns]

# %%
StageFactTests_1 = StageFactTests.iloc[:65000]
StageFactTests_2 = StageFactTests.iloc[65000:130000]
StageFactTests_3 = StageFactTests.iloc[130000:195000]
StageFactTests_4 = StageFactTests.iloc[195000:260000]
StageFactTests_5 = StageFactTests.iloc[260000:]

StageFactTests_1.to_csv('./StageFactTests_1.csv', index=False)
StageFactTests_2.to_csv('./StageFactTests_2.csv', index=False)
StageFactTests_3.to_csv('./StageFactTests_3.csv', index=False)
StageFactTests_4.to_csv('./StageFactTests_4.csv', index=False)
StageFactTests_5.to_csv('./StageFactTests_5.csv', index=False)

# %%
StageConfirmedCases_1 = StageConfirmedCases.iloc[:65000]
StageConfirmedCases_2 = StageConfirmedCases.iloc[65000:130000]
StageConfirmedCases_3 = StageConfirmedCases.iloc[130000:195000]
StageConfirmedCases_4 = StageConfirmedCases.iloc[195000:260000]
StageConfirmedCases_5 = StageConfirmedCases.iloc[260000:]

StageConfirmedCases_1.to_csv('./StageConfirmedCases_1.csv', index=False)
StageConfirmedCases_2.to_csv('./StageConfirmedCases_2.csv', index=False)
StageConfirmedCases_3.to_csv('./StageConfirmedCases_3.csv', index=False)
StageConfirmedCases_4.to_csv('./StageConfirmedCases_4.csv', index=False)
StageConfirmedCases_5.to_csv('./StageConfirmedCases_5.csv', index=False)

# %%
StageConfirmedDeaths_1 = StageConfirmedDeaths.iloc[:65000]
StageConfirmedDeaths_2 = StageConfirmedDeaths.iloc[65000:130000]
StageConfirmedDeaths_3 = StageConfirmedDeaths.iloc[130000:195000]
StageConfirmedDeaths_4 = StageConfirmedDeaths.iloc[195000:260000]
StageConfirmedDeaths_5 = StageConfirmedDeaths.iloc[260000:]

StageConfirmedDeaths_1.to_csv('./StageConfirmedDeaths_1.csv', index=False)
StageConfirmedDeaths_2.to_csv('./StageConfirmedDeaths_2.csv', index=False)
StageConfirmedDeaths_3.to_csv('./StageConfirmedDeaths_3.csv', index=False)
StageConfirmedDeaths_4.to_csv('./StageConfirmedDeaths_4.csv', index=False)
StageConfirmedDeaths_5.to_csv('./StageConfirmedDeaths_5.csv', index=False)

# %%
StageFactStatify_1 = StageFactStatify.iloc[:65000]
StageFactStatify_2 = StageFactStatify.iloc[65000:130000]
StageFactStatify_3 = StageFactStatify.iloc[130000:195000]
StageFactStatify_4 = StageFactStatify.iloc[195000:260000]
StageFactStatify_5 = StageFactStatify.iloc[260000:]

StageFactStatify_1.to_csv('./StageFactStatify_1.csv', index=False)
StageFactStatify_2.to_csv('./StageFactStatify_2.csv', index=False)
StageFactStatify_3.to_csv('./StageFactStatify_3.csv', index=False)
StageFactStatify_4.to_csv('./StageFactStatify_4.csv', index=False)
StageFactStatify_5.to_csv('./StageFactStatify_5.csv', index=False)

# %%
StageTests_1 = StageTests.iloc[:65000]
StageTests_2 = StageTests.iloc[65000:130000]
StageTests_3 = StageTests.iloc[130000:195000]
StageTests_4 = StageTests.iloc[195000:260000]
StageTests_5 = StageTests.iloc[260000:]

StageTests_1.to_csv('./StageTests_1.csv', index=False)
StageTests_2.to_csv('./StageTests_2.csv', index=False)
StageTests_3.to_csv('./StageTests_3.csv', index=False)
StageTests_4.to_csv('./StageTests_4.csv', index=False)
StageTests_5.to_csv('./StageTests_5.csv', index=False)

# %%
# StageFactTests.to_excel('./StageFactTests.xlsx', index=False)
# StageFactTests.to_excel('./StageFactTests.xlsm', index=False)

# %%
StageConfirmedCases_1 = StageConfirmedCases[:65000]
StageConfirmedDeaths_1 = StageConfirmedDeaths[:65000]

# %%
StageConfirmedCases_1.to_csv('./StageConfirmedCases_1.csv', index=False)
StageConfirmedDeaths_1.to_csv('./StageConfirmedDeaths_1.csv', index=False)

# %%
StageConfirmedCases_2 = StageConfirmedCases[65000:130000]
StageConfirmedDeaths_2 = StageConfirmedDeaths[65000:130000]
StageConfirmedCases_2.to_csv('./StageConfirmedCases_2.csv', index=False)
StageConfirmedDeaths_2.to_csv('./StageConfirmedDeaths_2.csv', index=False)

# %%
StageConfirmedCases_3 = StageConfirmedCases[130000:195000]
StageConfirmedDeaths_3 = StageConfirmedDeaths[130000:195000]
StageConfirmedCases_3.to_csv('./StageConfirmedCases_3.csv', index=False)
StageConfirmedDeaths_3.to_csv('./StageConfirmedDeaths_3.csv', index=False)

# %%
StageConfirmedCases_4 = StageConfirmedCases[195000:260000]
StageConfirmedDeaths_4 = StageConfirmedDeaths[195000:260000]
StageConfirmedCases_4.to_csv('./StageConfirmedCases_4.csv', index=False)
StageConfirmedDeaths_4.to_csv('./StageConfirmedDeaths_4.csv', index=False)

# %%
StageConfirmedCases_5 = StageConfirmedCases[260000:]
StageConfirmedDeaths_5 = StageConfirmedDeaths[260000:]
StageConfirmedCases_5.to_csv('./StageConfirmedCases_5.csv', index=False)
StageConfirmedDeaths_5.to_csv('./StageConfirmedDeaths_5.csv', index=False)

# %%
StageFactTests_1 = StageFactTests[:65000]
StageFactTests_2 = StageFactTests[65000:]
StageFactTests_1.to_csv('./StageFactTests_1.csv', index=False)
StageFactTests_2.to_csv('./StageFactTests_2.csv', index=False)

# %%
StageTests_1 = StageTests[:65000]
StageTests_2 = StageTests[65000:]
StageTests_1.to_csv('./StageTests_1.csv', index=False)
StageTests_2.to_csv('./StageTests_2.csv', index=False)

# %%
# StageFactStatify_1 = StageFactStatify[0:65000]
# StageFactStatify_2 = StageFactStatify[65000:130000]
# StageFactStatify_3 = StageFactStatify[130000:190000]
StageFactStatify_4 = StageFactStatify[190000:255000]
StageFactStatify_5 = StageFactStatify[255000:]
# StageFactStatify_1.to_csv('./StageFactStatify_1.csv', index=False)
# StageFactStatify_2.to_csv('./StageFactStatify_2.csv', index=False)
# StageFactStatify_3.to_csv('./StageFactStatify_3.csv', index=False)
StageFactStatify_4.to_csv('./StageFactStatify_4.csv', index=False)
StageFactStatify_5.to_csv('./StageFactStatify_5.csv', index=False)
